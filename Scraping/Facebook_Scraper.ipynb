# %% [markdown]
# # Import Libraries #1

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import Keys, ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
import time
import dateparser
import datetime
import pandas as pd
import numpy as np

# %%
# chrome_options = webdriver.ChromeOptions()
# prefs = {"profile.default_content_setting_values.notifications" : 2}
# chrome_options.add_experimental_option("prefs",prefs)

# driver= webdriver.Chrome(executable_path=r'C:\Program Files (x86)\chromedriver.exe',  chrome_options=chrome_options)

# %%
# service_obj = Service("C:\chromedriver.exe") # Choose services
# chrome_options = webdriver.ChromeOptions()
# prefs = {"profile.default_content_setting_values.notifications" : 2}
# chrome_options.add_experimental_option("prefs",prefs)
# driver = webdriver.Chrome(service=service_obj,chrome_options=chrome_options) #Making driver Object
f_service = Service("C:\geckodriver.exe")
driver = webdriver.Firefox(service=f_service)
# driver = webdriver.Firefox(executable_path=r'C:/Program Files (x86)/geckodriver-v0.32.0-win64/geckodriver')
driver.get("https://mbasic.facebook.com/") # Runing the url with the driver
# driver.maximize_window()

# %% [markdown]
# # Login

# %%
email = 'modelcoba@gmail.com'
password = 'skripsi2024!'

# %%
# Automated Login to Facebook login Page
driver.find_element(By.NAME,'email').send_keys(email)
time.sleep(5)
driver.find_element(By.NAME,"pass").send_keys(password)
time.sleep(5)
driver.find_element(By.NAME,'login').click()
time.sleep(5)

# %%
driver.find_element(By.CSS_SELECTOR,'input.bp[value = OKE]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# d:\Bank Mega\Final\Scraping\Facebook_Scraper.ipynb Cell 8 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Bank%20Mega/Final/Scraping/Facebook_Scraper.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> driver.find_element(By.CSS_SELECTOR,'input.bp[value = OKE]').click()
#
# File c:\Users\jmspa\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File c:\Users\jmspa\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
# ...

# %% [markdown]
# # Link Scrap

# %%
def get_fb_url(Facebook_account: str, driver: webdriver, cutoff_awal: datetime.date,cutoff_akhir: datetime.date, max_post: int=100):
    
    
    posts_url = []
    post_dates_list = []


    driver.get(f"https://mbasic.facebook.com/{Facebook_account}")
    time.sleep(2)
    try:
        try:
            Foto = driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[1]/div[1]/div[2]/div/div[4]/div/a')
            Foto.click()
        except:
            Foto = driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[1]/div[1]/div[4]/a[2]')
            Foto.click()
    except:
        try:
            Foto = driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[1]/div[1]/div[2]/div/div[5]/div/a/table/tbody/tr/td[1]')
            Foto.click()
        except:
            Foto = driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[1]/div[1]/div[2]/div/div[6]/div/a/table/tbody/tr/td[1]')
            Foto.click()
    time.sleep(3)
    # Click See all
    try:
        driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/table/tbody/tr/td/div[1]/div/div[1]/section/a').click()
    except:
        driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[2]/div[1]/section/a').click()
    Page = 0
    for i in range(50):
        time.sleep(3)
        for x in range(1,13):
            time.sleep(3)
            print(f'post number {x}')

            click = driver.find_element(By.XPATH,f'/html/body/div/div/div/div/table/tbody/tr/td/div/a[{x}]')
            time.sleep(3)
            click.click()

            post_time = driver.find_element(By.TAG_NAME,'abbr').text
            # if '2022' in post_time:
            #     post_time = driver.find_element(By.TAG_NAME,'abbr').text
            post_date = dateparser.parse(post_time)

            Link = driver.find_element(By.XPATH,'/html/head/link[1]').get_attribute('href')

            if post_date == None :
                print(post_time,';',Link)  
                post_time = 'Kemarin lusa pukul 07.00'
                post_date = dateparser.parse(post_time)
                                
            if post_date.date() > cutoff_akhir:
                print('post date more than cutoff akhir')
                time.sleep(3)
                driver.back()
                # for i in range(3):
                #     time.sleep(3)
                #     driver.back()

            if post_date.date() < cutoff_awal:
                print('post date less than cutoff awal')
                break
            
            try:
                if post_date.date() <= cutoff_akhir:
                    print(1)
                    time.sleep(1)
                    posts_url.append(Link)
                    post_dates_list.append(post_date.date())
                    time.sleep(1)
                    print(Link)
                    print(post_date.date())
                    time.sleep(3)
                    print(2)
                    driver.back()
            except:
                print('date > cutoff akhir')
                pass


                
            if len(posts_url) > max_post:
                print('len of post url more than max post')
                break 
            


        Page += 1
        print(Page)
        if post_date.date() < cutoff_awal:
                print('post date less than cutoff awal (II)')
                break
        time.sleep(3)
        driver.find_element(By.XPATH,'/html/body/div/div/div/div/table/tbody/tr/td/div/span/div/a').click()

    return posts_url, post_dates_list

# %% [markdown]
# ## Filter Account Name, Tanggal awal, Tanggal akhir

# %%
# # BANK KECIL 1
# banks = ["bankocbcnisp","dbsdigibankID","PermataBank","CIMBIndonesia"] ## Masukan nama nama account FB yang ingin di scrap ke dalam list
# Tanggal_awal = datetime.date(2023,8,1)
# Tanggal_akhir = datetime.date(2023,8,6)
# print( Tanggal_awal , Tanggal_akhir)

# %%
# # BANK KECIL 2
# banks = ["bankneocommerce","jeniusconnect","JadiJagoOfficial","blubybcadigital"] ## Masukan nama nama account FB yang ingin di scrap ke dalam list
# Tanggal_awal = datetime.date(2023,7,24)
# Tanggal_akhir = datetime.date(2023,7,31)
# print( Tanggal_awal , Tanggal_akhir)

# %%
# SEABANK
banks = ["SeaBankIndonesia"] ## Masukan nama nama account FB yang ingin di scrap ke dalam list
Tanggal_awal = datetime.date(2023,11,20)
Tanggal_akhir = datetime.date(2023,11,30)
#print( Tanggal_awal , Tanggal_akhir)

# %%
#Running Setelah Banks 1

#banks = ["BRIofficialpage"]
#Tanggal_awal = datetime.date(2023,4,24)
#Tanggal_akhir = datetime.date(2023,4,30)
#print( Tanggal_awal , Tanggal_akhir)

# %%
# banks = ["BNI"]
# Tanggal_awal = datetime.date(2023,8,7)
# Tanggal_akhir = datetime.date(2023,8,13)
# print( Tanggal_awal , Tanggal_akhir)

# %%
#banks = ["bankmandiri"]
#Tanggal_awal = datetime.date(2023,5,1)
#Tanggal_akhir = datetime.date(2023,5,7)
#print( Tanggal_awal , Tanggal_akhir)

# %%
# ## Running Setelah Banks 2

# banks = ["BankBCA"]
# Tanggal_awal = datetime.date(2023,5,1)
# Tanggal_akhir = datetime.date(2023,5,7)
# #print( Tanggal_awal , Tanggal_akhir)

# %%
banks_url = []
url_date = []
for b in banks:
    fb_post_url = get_fb_url(Facebook_account= b, driver=driver, cutoff_awal= Tanggal_awal ,cutoff_akhir = Tanggal_akhir, max_post=100)
    link_list = []
    date_link_list = []
    link_list.append(fb_post_url[0])
    date_link_list.append(fb_post_url[1])
    for x in link_list:
        banks_url.append(x)
    for i in date_link_list:
        url_date.append(i)
# Out:
# post number 1
# 1
# https://www.facebook.com/photo.php?fbid=360217703171881&id=100075509634420&set=a.287767670416885&eav=AfZaVfpe3zNhc7yuDsa3nnG-0Y0C0YToX0eVLUoesukFDCSDDPiDuFkULWO2jGBFAWc&paipv=0
# 2023-11-30
# 2
# post number 2
# 1
# https://www.facebook.com/photo.php?fbid=360217183171933&id=100075509634420&set=a.287767670416885&eav=AfaQrYDQAelXHzwjKbNFzqGP9ROSWAsjGSmUPyC1RntVIaMleDsjCxQs3k6Go8SvtJM&paipv=0
# 2023-11-30
# 2
# post number 3
# 1
# https://www.facebook.com/photo.php?fbid=360213856505599&id=100075509634420&set=a.287767670416885&eav=AfaQImWGaIMe4sN2A80ydr3M7RRkgmAYdt4CaVZanpCWIgkSC1RY65yZqDHugP-aME8&paipv=0
# 2023-11-30
# 2
# post number 4
# 1
# https://www.facebook.com/photo.php?fbid=360097079850610&id=100075509634420&set=a.287767670416885&eav=AfYelfizHEwWj4OtloKYqqro3f9A8HSDwr1-OeraALpTd-Cv_hpJLgfwyMfj1dzvuBY&paipv=0
# 2023-11-29
# 2
# post number 5
# 1
# ...

# %%
Links = []
date_url = []
for i in banks_url:
    for x in i:
        Links.append(x)

for j in url_date:
    for z in j:
        date_url.append(z)

# %%
df_url = pd.DataFrame(list(zip(Links,date_url)), columns=['URL','Post_Date'])
df_url
# Out:
#                                                   URL   Post_Date
# 0   https://www.facebook.com/photo.php?fbid=360217...  2023-11-30
# 1   https://www.facebook.com/photo.php?fbid=360217...  2023-11-30
# 2   https://www.facebook.com/photo.php?fbid=360213...  2023-11-30
# 3   https://www.facebook.com/photo.php?fbid=360097...  2023-11-29
# 4   https://www.facebook.com/photo.php?fbid=359734...  2023-11-29
# 5   https://www.facebook.com/photo.php?fbid=359733...  2023-11-29
# 6   https://www.facebook.com/photo.php?fbid=359731...  2023-11-29
# 7   https://www.facebook.com/photo.php?fbid=359731...  2023-11-29
# 8   https://www.facebook.com/photo.php?fbid=359731...  2023-11-29
# 9   https://www.facebook.com/photo.php?fbid=359731...  2023-11-29
# 10  https://www.facebook.com/photo.php?fbid=359718...  2023-11-29
# 11  https://www.facebook.com/photo.php?fbid=359717...  2023-11-29
# 12  https://www.facebook.com/photo.php?fbid=359574...  2023-11-28
# ...

# %%
# # Simpan Link Sebelum Scraping Komentar

# df_url.to_excel('FB_BankKecil1_(LINK).xlsx')

# %%
# # Simpan Link Sebelum Scraping Komentar

# df_url.to_excel('FB_BankKecil_(LINK).xlsx')

# %%
## Simpan Link Sebelum Scraping Komentar

df_url.to_excel('FB_Seabank_(LINK).xlsx')

# %%
## Simpan Link Sebelum Scraping Komentar

#df_url.to_excel('FB_27-5mar_BNI_(LINK).xlsx')

# %%
## Simpan Link Sebelum Scraping Komentar

#df_url.to_excel('FB_BRI_(LINK).xlsx')

# %%
## Simpan Link Sebelum Scraping Komentar

#df_url.to_excel('FB_Mandiri_(LINK).xlsx')

# %%
# ## Simpan Link Sebelum Scraping Komentar

# df_url.to_excel('FB_BCA_(LINK).xlsx')

# %% [markdown]
# ## Comments scrap

# %%
import time
user_names=[]
user_comments=[]
comments_date=[]
url_list = []
bank_list = []
platform = []
url=df_url.iloc[:,0]


for n in url:
    time.sleep(2)
    try:
        driver.get(n)
        time.sleep(4)

        # postingan bukan dari foto
        try:
            time.sleep(5)
            try:
                view_posts = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[1]/div[3]/span/a')
            except:                                       
                view_posts = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[1]/div[3]/span/a')
            time.sleep(1)
            view_posts.click()

            time.sleep(10)
            com_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[4]/div/div/div[2]/div[2]/div/div/div')
            driver.execute_script("arguments[0].click();",com_filter)

            menu_item = driver.find_element(By.CSS_SELECTOR,'div.x1n2onr6[role = menu]')
            all_com = menu_item.find_elements(By.CSS_SELECTOR,'div.x1i10hfl[role = menuitem]')[2]
            driver.execute_script("arguments[0].click();",all_com)
            time.sleep(3)
            try:
                show_oth_com = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[4]/div/div/div[2]/div[4]/div[1]/div[2]')
                time.sleep(2)

                while show_oth_com:
                    show_oth_com = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[4]/div/div/div[2]/div[4]/div[1]/div[2]')
                    driver.execute_script("arguments[0].click();",show_oth_com)
                    time.sleep(3)
                    for i in range(0,5):
                        driver.execute_script("window.scrollTo(0,Math.max(document.documentElement.scrollHeight,document.body.scrollHeight,document.documentElement.clientHeight))")
                    time.sleep(5)

                comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[4]/div/div/div[2]/ul')
                comments = comment_cont.find_elements(By.CSS_SELECTOR,'div.x1n2onr6[role = article]')
                for c in comments:
                    name = c.find_element(By.CSS_SELECTOR,'span.x193iq5w').text
                    cont_cont = c.find_element(By.CSS_SELECTOR,'div.x11i5rnm')
                    content = cont_cont.find_element(By.CSS_SELECTOR,'div[dir = auto]').text
                    date_cont = c.find_element(By.CSS_SELECTOR,'ul.x1n0m28w')
                    date = date_cont.find_elements(By.TAG_NAME,'li')[-1].text
                    com_date = dateparser.parse(date)
                    account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[2]/div/div[2]/div/div[1]/span/h2/span[1]/a/strong/span').text
                    url_list.append(driver.current_url)
                    user_names.append(name)
                    user_comments.append(content)
                    comments_date.append(com_date)
                    bank_list.append(account_name)
                    platform.append('Facebook')
                    print(driver.current_url,';',name,';',content,';',com_date,';',account_name)

                        
            except:
                comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[4]/div/div/div[2]/ul')
                comments = comment_cont.find_elements(By.CSS_SELECTOR,'div.x1n2onr6[role = article]')
                for c in comments:
                    name = c.find_element(By.CSS_SELECTOR,'span.x193iq5w').text
                    cont_cont = c.find_element(By.CSS_SELECTOR,'div.x11i5rnm')
                    content = cont_cont.find_element(By.CSS_SELECTOR,'div[dir = auto]').text
                    date_cont = c.find_element(By.CSS_SELECTOR,'ul.x1n0m28w')
                    date = date_cont.find_elements(By.TAG_NAME,'li')[-1].text
                    com_date = dateparser.parse(date)
                    account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div/div/div/div/div/div/div/div/div/div/div/div[8]/div/div/div[2]/div/div[2]/div/div[1]/span/h2/span[1]/a/strong/span').text
                    url_list.append(driver.current_url)
                    user_names.append(name)
                    user_comments.append(content)
                    comments_date.append(com_date)
                    bank_list.append(account_name)
                    platform.append('Facebook')
                    print(driver.current_url,';',name,';',content,';',com_date,';',account_name)

                        
           
        # postingan dari foto
        except:
            try:    
                try:                                           
                    com_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div[2]/div/div[3]/div[2]/div/div/div[1]/div[4]/div[1]/div/div/div')
                except:                                        
                    com_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/div[1]/div/div/div')
            except:
                com_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/div[1]/div[1]/div/div/div')
            driver.execute_script("arguments[0].click();",com_filter)

            menu_item = driver.find_element(By.CSS_SELECTOR,'div.x1n2onr6[role = menu]')
            all_com = menu_item.find_elements(By.CSS_SELECTOR,'div.x1i10hfl[role = menuitem]')[2]
            driver.execute_script("arguments[0].click();",all_com)
            time.sleep(3)

            try:
                # oth_com_cont = driver.find_element(By.CSS_SELECTOR,'div.x78zum5')
                try:
                    try:
                        show_oth_com = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div[2]/div/div[3]/div[2]/div/div/div[1]/div[4]/div[2]/div[1]/div[2]/span/span')
                    except:
                        show_oth_com = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/div[2]/div/div[2]/span/span')
                except:
                    show_oth_com = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/div[1]/div[2]/div[1]/div[2]')
                
                time.sleep(2)
                
                try:
                    while show_oth_com:
                        driver.execute_script("arguments[0].click();",show_oth_com)
                        time.sleep(5)
                except:
                    pass
                    
                time.sleep(2)

                try:
                    try:
                        comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div[2]/div/div[3]/div[2]/div/div/div[1]/div[4]/ul')
                    except:
                        comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/ul')
                except:
                    comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/div[1]/ul')
                comments = comment_cont.find_elements(By.CSS_SELECTOR,'div.x1n2onr6[role = article]')
                
                for c in comments:
                    name = c.find_element(By.CSS_SELECTOR,'span.x193iq5w').text
                    cont_cont = c.find_element(By.CSS_SELECTOR,'div.x11i5rnm')
                    try:
                        content = cont_cont.find_element(By.CSS_SELECTOR,'div[dir = auto]').text
                    except:
                        content = np.nan
                    date_cont = c.find_element(By.CSS_SELECTOR,'ul.x1n0m28w')
                    date = date_cont.find_elements(By.TAG_NAME,'li')[-1].text
                    com_date = dateparser.parse(date)
                    try:
                        try:
                            account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div[2]/div/div[3]/div[2]/div/div/div[1]/div[4]/ul/li[1]/div[1]/div/div[2]/div/div[1]/div/div/div/div/span/a/span/span').text
                        except:
                            account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[1]/div[1]/div[1]/div[2]/div/div[1]/span/div/h2/span/span/a').text
                    except:
                        account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[1]/div[1]/div[1]/div[2]/div/div[1]/span/div/h2/span/span/a').text
                    url_list.append(driver.current_url)
                    user_names.append(name)
                    user_comments.append(content)
                    comments_date.append(com_date)
                    bank_list.append(account_name)
                    platform.append('Facebook')
                    print(driver.current_url,';',name,';',content,';',com_date,';',account_name)
                    
            except:
                try:
                    try:
                        comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div[2]/div/div[3]/div[2]/div/div/div[1]/div[4]/ul')
                    except:
                        comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/ul')
                except:
                    comment_cont = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[4]/div[1]/ul')
                comments = comment_cont.find_elements(By.CSS_SELECTOR,'div.x1n2onr6[role = article]')
                
                for c in comments:
                    name = c.find_element(By.CSS_SELECTOR,'span.x193iq5w').text
                    cont_cont = c.find_element(By.CSS_SELECTOR,'div.x11i5rnm')
                    try:
                        content = cont_cont.find_element(By.CSS_SELECTOR,'div[dir = auto]').text
                    except:
                        content = np.nan
                    date_cont = c.find_element(By.CSS_SELECTOR,'ul.x1n0m28w')
                    date = date_cont.find_elements(By.TAG_NAME,'li')[-1].text
                    com_date = dateparser.parse(date)
                    try:
                        try:
                            account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div[2]/div/div[3]/div[2]/div/div/div[1]/div[4]/ul/li[1]/div[1]/div/div[2]/div/div[1]/div/div/div/div/span/a/span/span').text
                        except:
                            account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[1]/div[1]/div[1]/div[2]/div/div[1]/span/div/h2/span/span/a').text
                    except:
                        account_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[3]/div/div/div[1]/div[1]/div/div[2]/div/div/div/div[1]/div[1]/div[1]/div[1]/div[2]/div/div[1]/span/div/h2/span/span/a').text
                    url_list.append(driver.current_url)
                    user_names.append(name)
                    user_comments.append(content)
                    comments_date.append(com_date)
                    bank_list.append(account_name)
                    platform.append('Facebook')
                    print(driver.current_url,';',name,';',content,';',com_date,';',account_name)
    except:
        print('pass',';',driver.current_url)
        pass
# Out:
# pass ; https://www.facebook.com/photo.php?fbid=360217703171881&id=100075509634420&set=a.287767670416885&eav=AfZaVfpe3zNhc7yuDsa3nnG-0Y0C0YToX0eVLUoesukFDCSDDPiDuFkULWO2jGBFAWc&paipv=0
# pass ; https://www.facebook.com/photo.php?fbid=360217183171933&id=100075509634420&set=a.287767670416885&eav=AfaQrYDQAelXHzwjKbNFzqGP9ROSWAsjGSmUPyC1RntVIaMleDsjCxQs3k6Go8SvtJM&paipv=0
# pass ; https://www.facebook.com/photo.php?fbid=360213856505599&id=100075509634420&set=a.287767670416885&eav=AfaQImWGaIMe4sN2A80ydr3M7RRkgmAYdt4CaVZanpCWIgkSC1RY65yZqDHugP-aME8&paipv=0
# pass ; https://www.facebook.com/photo.php?fbid=360097079850610&id=100075509634420&set=a.287767670416885&eav=AfYelfizHEwWj4OtloKYqqro3f9A8HSDwr1-OeraALpTd-Cv_hpJLgfwyMfj1dzvuBY&paipv=0
# pass ; https://www.facebook.com/photo.php?fbid=359734786553506&id=100075509634420&set=a.287767670416885&eav=AfZrGGPxq-8hRS57ByQdKUVA9mFFqdhVs_NpwS1qgVL7cxJkyAm5uxqoeZUjZ9lupI4&paipv=0
# ...

# %%
df = pd.DataFrame(list(zip(url_list,user_names, user_comments, comments_date,bank_list,platform)), columns=["url","Name", "Comments", "Comments_Date","Bank","platform"])
df
# Out:
# Empty DataFrame
# Columns: [url, Name, Comments, Comments_Date, Bank, platform]
# Index: []

# %%
df1 = df.copy()
df1 = pd.merge(df,df_url, left_on="url", right_on="URL", how = 'left' )
df_final = df1[['url','Post_Date','Name','Comments','Comments_Date','Bank','platform']]
df_final
# Out:
# Empty DataFrame
# Columns: [url, Post_Date, Name, Comments, Comments_Date, Bank, platform]
# Index: []

# %%
# # Save Komentar ke excel

# df_final.to_excel('scrap_fb_BankKecil.xlsx')

# %%
# # Save Komentar ke excel

# df_final.to_excel('scrap_fb_BankKecil2.xlsx')

# %%
# Save Komentar ke excel

df_final.to_excel('D:/scrap_fb_Seabank.xlsx')

# %%
## Save Komentar ke excel

#df_final.to_excel('scrap_fb_27-5Mar23_BNI.xlsx')

# %%
# Save Komentar ke excel

df_final.to_excel('D:/scrap_fb_BNI.xlsx')

# %%
## Save Komentar ke excel

#df_final.to_excel('scrap_fb_Mandiri.xlsx')

# %%
# df_final.to_excel('scrap_fb_BCA.xlsx')
